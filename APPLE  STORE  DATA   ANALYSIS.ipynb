# %% [markdown]
# # APPLE STORE DATA ANALYSIS

# %% [markdown]
# # IMPORT LIBRARIES

# %%
#import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline
from warnings import filterwarnings
filterwarnings(action='ignore')

# %%
#import dataset of Apple Store
ds=pd.read_csv(r"C:\Users\Rehan\OneDrive\Desktop\Diwali Sales Data.csv",encoding='ISO-8859-1')
ds
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11246     Maharashtra   Western         Chemical           Office       4
# 11247         Haryana  Northern       Healthcare       Veterinary       3
# 11248  Madhya Pradesh   Central          Textile           Office       4
# 11249       Karnataka  Southern      Agriculture           Office       3
# 11250     Maharashtra   Western       Healthcare           Office       3
#
#         Amount  Status  unnamed1
# 0      23952.0     NaN       NaN
# 1      23934.0     NaN       NaN
# 2      23924.0     NaN       NaN
# 3      23912.0     NaN       NaN
# 4      23877.0     NaN       NaN
# ...        ...     ...       ...
# 11246    370.0     NaN       NaN
# 11247    367.0     NaN       NaN
# 11248    213.0     NaN       NaN
# 11249    206.0     NaN       NaN
# 11250    188.0     NaN       NaN
#
# [11251 rows x 15 columns]

# %%
ds.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# 2  23924.0     NaN       NaN
# 3  23912.0     NaN       NaN
# 4  23877.0     NaN       NaN

# %%
ds.tail()
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# 11246     Maharashtra   Western     Chemical           Office       4   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary       3   367.0
# 11248  Madhya Pradesh   Central      Textile           Office       4   213.0
# 11249       Karnataka  Southern  Agriculture           Office       3   206.0
# 11250     Maharashtra   Western   Healthcare           Office       3   188.0
#
#        Status  unnamed1
# 11246     NaN       NaN
# 11247     NaN       NaN
# 11248     NaN       NaN
# 11249     NaN       NaN
# 11250     NaN       NaN

# %% [markdown]
# # DATA CLEANING

# %%
ds.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
ds.shape
# Out:
# (11251, 15)

# %%
#lets remove unwanted columns(Status,unnamed1)
ds=ds.drop(['Status','unnamed1'],axis=1)

# %%
#remove NAN values of Amount Attribute
ds.dropna(subset=["Amount"],inplace=True)

# %%
ds.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
ds.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610858
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
ds.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ds.shape
# Out:
# (11239, 13)

# %% [markdown]
# # DATA VISUALIZATION

# %%
ds.corr()
# Out:
#                  User_ID       Age  Marital_Status    Orders    Amount
# User_ID         1.000000  0.022338        0.004345 -0.016022 -0.011997
# Age             0.022338  1.000000       -0.012344  0.008090  0.030941
# Marital_Status  0.004345 -0.012344        1.000000 -0.003487 -0.017493
# Orders         -0.016022  0.008090       -0.003487  1.000000 -0.013183
# Amount         -0.011997  0.030941       -0.017493 -0.013183  1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(ds.corr(),cmap='seismic',annot=True)
plt.title('HEATMAP')
plt.show()

# %%
ds['State'].value_counts()
# Out:
# Uttar Pradesh       1944
# Maharashtra         1525
# Karnataka           1304
# Delhi               1104
# Madhya Pradesh       921
# Andhra Pradesh       811
# Himachal Pradesh     608
# Kerala               453
# Haryana              452
# Bihar                434
# Gujarat              427
# Jharkhand            380
# Uttarakhand          320
# Rajasthan            231
# Punjab               200
# Telangana            125
# Name: State, dtype: int64

# %%
ds['State'].value_counts()[0:10]
# Out:
# Uttar Pradesh       1944
# Maharashtra         1525
# Karnataka           1304
# Delhi               1104
# Madhya Pradesh       921
# Andhra Pradesh       811
# Himachal Pradesh     608
# Kerala               453
# Haryana              452
# Bihar                434
# Name: State, dtype: int64

# %%
ds['State'].value_counts()[0:10].keys()
# Out:
# Index(['Uttar Pradesh', 'Maharashtra', 'Karnataka', 'Delhi', 'Madhya Pradesh',
#        'Andhra Pradesh', 'Himachal Pradesh', 'Kerala', 'Haryana', 'Bihar'],
#       dtype='object')

# %%
#plotting bar
plt.figure(figsize=(28,13))
plt.bar(list(ds['State'].value_counts().keys()),ds['State'].value_counts(),color='darkblue',edgecolor='red')
plt.xlabel('STATES')
plt.ylabel('SALES')
plt.title('STATES VS SALES')
plt.show()

# %%
#plotting pie
plt.figure(figsize=(15,15))
plt.pie(list(ds['State'].value_counts()),labels=list(ds['State'].value_counts().keys()),autopct='%1.1f%%')
plt.title('STATES WITH SALES')
plt.show()

# %%
#plotting pie
plt.figure(figsize=(8,10))
plt.pie(list(ds['State'].value_counts()[0:5]),labels=list(ds['State'].value_counts().keys()[0:5]),autopct='%1.1f%%')
plt.title('Top 5 States with high sales')
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.bar(list(ds['State'].value_counts()[11:16].keys()),ds['State'].value_counts()[11:16],color='yellow',edgecolor='blue')
plt.title('Bottom 5 States with Low Sales')
plt.xlabel('STATES')
plt.ylabel('NO OF SALES')
plt.show()

# %%
ds['Zone'].value_counts()
# Out:
# Central     4289
# Southern    2693
# Western     1952
# Northern    1491
# Eastern      814
# Name: Zone, dtype: int64

# %%
ds['Zone'].value_counts().keys()
# Out:
# Index(['Central', 'Southern', 'Western', 'Northern', 'Eastern'], dtype='object')

# %%
plt.figure(figsize=(7,5))
plt.bar(list(ds['Zone'].value_counts().keys()),ds['Zone'].value_counts(),color='Pink',edgecolor='green')
plt.xlabel('Zone')
plt.title('SALES ACCORDING TO  THEIR ZONE')
plt.show()

# %%
#plotting pie for zone
plt.figure(figsize=(5,10))
plt.pie(list(ds['Zone'].value_counts()),labels=list(ds['Zone'].value_counts().keys()),autopct='%1.1f%%')
plt.show()

# %%
ds['Occupation'].value_counts()
# Out:
# IT Sector          1583
# Healthcare         1408
# Aviation           1310
# Banking            1137
# Govt                854
# Hospitality         703
# Media               637
# Automobile          565
# Chemical            541
# Lawyer              531
# Retail              501
# Food Processing     423
# Construction        414
# Textile             349
# Agriculture         283
# Name: Occupation, dtype: int64

# %%
ds['Occupation'].value_counts().keys()
# Out:
# Index(['IT Sector', 'Healthcare', 'Aviation', 'Banking', 'Govt', 'Hospitality',
#        'Media', 'Automobile', 'Chemical', 'Lawyer', 'Retail',
#        'Food Processing', 'Construction', 'Textile', 'Agriculture'],
#       dtype='object')

# %%
plt.figure(figsize=(25,10))
plt.bar(list(ds["Occupation"].value_counts().keys()),ds['Occupation'].value_counts(),color='darkgreen',edgecolor='red')
plt.title('OCCUPATION WISE - SALES')
plt.xlabel('OCCUPATION')
plt.ylabel('NO OF SALES')
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.bar(list(ds["Occupation"].value_counts()[0:5].keys()),ds['Occupation'].value_counts()[0:5],color='orange',edgecolor='blue')
plt.title(' HIGH SALES BY OCCUPATION')
plt.xlabel('OCCUPATION')
plt.ylabel('NO OF SALES')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.pie(list(ds["Occupation"].value_counts()[10:15]),labels=list(ds['Occupation'].value_counts().keys()[10:15]),autopct='%1.1f%%')
plt.title('LOW SALES BY OCCUPATION')
plt.show()

# %%
ds['Gender'].value_counts()
# Out:
# F    7832
# M    3407
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(3,5))
plt.bar(list(ds['Gender'].value_counts().keys()),ds['Gender'].value_counts(),color=['pink','blue'],edgecolor=['brown','red'])
plt.xlabel('GENDER')
plt.ylabel('NO OF SALES')
plt.title('FEMALE VS MALE')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.pie(list(ds['Marital_Status'].value_counts()),labels=list(ds['Marital_Status'].value_counts().keys()),autopct='%1.1f%%')
plt.title('MARITAL STATUS OF APPLE MOBILE PURCHASER')
plt.show()

# %%
plt.figure(figsize=(25,15))
sns.histplot(ds['State'],bins=15,kde=True,color='blue',edgecolor='darkred')
plt.xlabel('State')
plt.title('STATES')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25,15))
sns.histplot(ds['Occupation'],kde=True,color='brown',bins=15,edgecolor='darkblue')
plt.title('OCCUPATION')
plt.xlabel('OCCUPATION')
plt.ylabel('NO OF SALES')
plt.tight_layout()
plt.show()

# %%
ds['Age Group'].value_counts().keys()
# Out:
# Index(['26-35', '36-45', '18-25', '46-50', '51-55', '55+', '0-17'], dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.histplot(ds['Age Group'],bins=15,kde=True,color='red')
plt.tight_layout()
plt.title('AGE -GROUP WISE APPLE MOBILE BUYERS')
plt.show()

# %%
ds['Product_Category'].value_counts()
# Out:
# Clothing & Apparel       2655
# Food                     2490
# Electronics & Gadgets    2087
# Footwear & Shoes         1059
# Household items           520
# Beauty                    422
# Games & Toys              386
# Sports Products           356
# Furniture                 352
# Pet Care                  212
# Office                    113
# Stationery                112
# Books                     103
# Auto                       97
# Decor                      96
# Veterinary                 81
# Tupperware                 72
# Hand & Power Tools         26
# Name: Product_Category, dtype: int64

# %%
plt.figure(figsize=(35,15))
sns.histplot(ds['Product_Category'],bins=15,kde=True,color='orange')
plt.title('PRODUCT CATEGORY')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,10))
plt.pie(list(ds['Product_Category'].value_counts()[0:5]),labels=list(ds['Product_Category'].value_counts().keys()[0:5]),autopct='%1.1f%%')
plt.title('TOP 5 PRODUCT CATEGORY ACCORDING TO SALE')
plt.show()

# %%
sns.lmplot(x="Age",y="Amount",data=ds)

# %%
plt.figure(figsize=(22,10))
sns.barplot(data = ds, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
plt.figure(figsize=(25,10))
sns.barplot(data = ds, x = 'State',y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
sns.barplot(data = ds, x = 'Marital_Status',y= 'Amount', hue='Gender')
plt.show()

# %%
plt.figure(figsize=(25,8))
plt.bar(ds['State'],ds['Amount'],color='maroon')
plt.title('PRICE  OF APPLE MOBILE ACCORDING TO STATES')
plt.show()

# %% [markdown]
# # TRAINING AND TESTING DATASET

# %%
ds.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ds['Gender']=pd.Categorical(ds['Gender'])

# %%
x=ds[['Gender','Age','Marital_Status','State','Zone','Occupation','Product_Category']]
y=ds[['Amount']]

# %%
x.shape
# Out:
# (11239, 7)

# %%
y.shape
# Out:
# (11239, 1)

# %%
y
# Out:
#         Amount
# 0      23952.0
# 1      23934.0
# 2      23924.0
# 3      23912.0
# 4      23877.0
# ...        ...
# 11246    370.0
# 11247    367.0
# 11248    213.0
# 11249    206.0
# 11250    188.0
#
# [11239 rows x 1 columns]

# %%
x
# Out:
#       Gender  Age  Marital_Status           State      Zone       Occupation  \
# 0          F   28               0     Maharashtra   Western       Healthcare
# 1          F   35               1  Andhra Pradesh  Southern             Govt
# 2          F   35               1   Uttar Pradesh   Central       Automobile
# 3          M   16               0       Karnataka  Southern     Construction
# 4          M   28               1         Gujarat   Western  Food Processing
# ...      ...  ...             ...             ...       ...              ...
# 11246      M   19               1     Maharashtra   Western         Chemical
# 11247      M   33               0         Haryana  Northern       Healthcare
# 11248      F   40               0  Madhya Pradesh   Central          Textile
# 11249      M   37               0       Karnataka  Southern      Agriculture
# 11250      F   19               0     Maharashtra   Western       Healthcare
#
#       Product_Category
# 0                 Auto
# 1                 Auto
# 2                 Auto
# 3                 Auto
# 4                 Auto
# ...                ...
# 11246           Office
# 11247       Veterinary
# 11248           Office
# 11249           Office
# 11250           Office
#
# [11239 rows x 7 columns]

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((8991, 7), (2248, 7))

# %%
y_train.shape,y_test.shape
# Out:
# ((8991, 1), (2248, 1))

# %%
x=x.apply(pd.to_numeric,errors='coerce')
y=y.apply(pd.to_numeric,errors='coerce')

# %%
x.fillna(0,inplace=True)
y.fillna(0,inplace=True)

# %% [markdown]
# # LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# array([9048.73334356])

# %%
model.coef_
# Out:
# array([[   0.        ,   11.81911771, -115.46387459,    0.        ,
#            0.        ,    0.        ,    0.        ]])
